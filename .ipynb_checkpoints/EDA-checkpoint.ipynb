# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
team_skaters=pd.read_csv('relative_stats_trophy/relative_skater_hart_teams.csv')
team_goalies=pd.read_csv('relative_stats_trophy/relative_goalie_hart_teams.csv')
nba_teammates=pd.read_csv('relative_stats_trophy/relative_mvp_teams.csv')

# %%
nba_teammates_all=pd.read_csv('relative_stats_all/relative_every_player.csv')
team_skaters_all=pd.read_csv('relative_stats_all/relative_skater_stats.csv')
team_goalies_all=pd.read_csv('relative_stats_all/relative_goalies_all.csv')

# %%
team_skaters
# Out:
#       index  season   age        gp     goals   assists    points    plusmin  \
# 0      1936    1940  29.0  0.030128  0.000000  0.000000  0.000000        NaN
# 1      1937    1940  32.0  0.361542  0.000000  0.000000  0.000000        NaN
# 2      1938    1940  21.0  0.060257  0.000000  0.000000  0.000000        NaN
# 3      1939    1940  28.0  0.030128  0.000000  0.000000  0.000000        NaN
# 4      1940    1940  22.0  1.446167  0.164053  0.000000  0.066798        NaN
# ...     ...     ...   ...       ...       ...       ...       ...        ...
# 1954     20    2019  22.0  1.564288  4.902468  3.630835  4.105403 -52.948052
# 1955     21    2019  28.0  0.732641  0.239145  0.427157  0.356992  -7.844156
# 1956     22    2019  20.0  1.485084  0.717434  1.851014  1.427966 -23.532468
# 1957     23    2019  28.0  1.623691  5.380758  3.773220  4.373147  -7.844156
# 1958     24    2019  32.0  0.930652  0.239145  1.067893  0.758607 -23.532468
#
#            plm  goals_ev  ...  faceoff_wins  faceoff_losses     block  \
# 0     0.000000       NaN  ...           NaN             NaN       NaN
# 1     0.000000       NaN  ...           NaN             NaN       NaN
# 2     0.000000       NaN  ...           NaN             NaN       NaN
# 3     0.000000       NaN  ...           NaN             NaN       NaN
# 4     2.210484       NaN  ...           NaN             NaN       NaN
# ...        ...       ...  ...           ...             ...       ...
# 1954  1.243225  3.236815  ...      5.254310        5.085205  1.074318
# 1955  0.710414  0.308268  ...      0.000000        0.000000  0.749524
# 1956  1.243225  0.924804  ...      0.012079        0.012079  2.323525
# 1957  1.642833  3.699217  ...      6.111910        5.399256  0.999366
# 1958  0.355207  0.308268  ...      0.000000        0.000000  1.773874
#
#       faceoff_pct  shot_pct       gpg   toi_avg               name  team  pos
# 0             NaN       NaN  0.000000       NaN          Bert Peer   DET   RW
# 1             NaN       NaN  0.000000       NaN         Hec Kilrea   DET   LW
# 2             NaN       NaN  0.000000       NaN         Buck Jones   DET    D
# 3             NaN       NaN  0.000000       NaN         Ron Hudson   DET   RW
# 4             NaN       NaN  0.129239       NaN      Jack Stewart*   DET    D
# ...           ...       ...       ...       ...                ...   ...  ...
# 1954     1.901867  2.729530  3.822751  1.258133      Brayden Point   TBL    C
# 1955     0.000000  0.605506  0.398151  1.036779          Jan Rutta   TBL    D
# 1956     1.871916  0.596045  0.589263  1.191380  Mikhail Sergachev   TBL    D
# 1957     1.987975  2.445311  4.042201  1.216968     Steven Stamkos   TBL    C
# 1958     0.000000  0.446162  0.313438  1.365029     Anton Stralman   TBL    D
#
# [1959 rows x 29 columns]

# %%
team_goalies
# Out:
#      Unnamed: 0  index  season  Unnamed: 0.1  age        gp        gs  \
# 0             0     35    1924      0.933333   31  1.375000       NaN
# 1             1     37    1924      0.986667   29  0.125000       NaN
# 2             2     44    1925      0.946237   27  1.956522       NaN
# 3             3     50    1925      1.075269   24  0.065217       NaN
# 4             4     53    1926      0.905983   33  1.694118       NaN
# ..          ...    ...     ...           ...  ...       ...       ...
# 224         224   4140    2018      1.000483   28  1.411232  1.420142
# 225         225   4174    2018      1.008700   31  1.376812  1.494886
# 226         226   4211    2019      0.995038   26  0.888971  0.951220
# 227         227   4257    2019      1.005907   28  0.102574  0.109756
# 228         228   4277    2019      1.010633   24  1.812132  1.939024
#
#          wins    losses      ties  ...  really_bad_starts  ga_pct_minus  \
# 0    1.875000  0.875000       NaN  ...                NaN           NaN
# 1    0.125000  0.125000       NaN  ...                NaN           NaN
# 2    2.620690  1.379310  2.000000  ...                NaN           NaN
# 3    0.000000  0.000000  0.000000  ...                NaN           NaN
# 4    2.086957  1.147826  2.727273  ...                NaN           NaN
# ..        ...       ...       ...  ...                ...           ...
# 224  1.943352  0.974359  0.962838  ...           0.976864      1.339553
# 225  1.270653  1.558974  1.925676  ...           1.709512      1.434269
# 226  1.536585  0.465000  0.000000  ...           0.459259      1.404085
# 227  0.146341  0.093000  0.000000  ...           0.229630      0.000000
# 228  2.853659  0.930000  1.372694  ...           1.607407      1.142540
#
#      gs_above_avg  goals_scored   assists    points       plm       mpg  \
# 0             NaN           NaN       NaN       NaN       NaN  1.015364
# 1             NaN           NaN       NaN       NaN       NaN  0.988414
# 2             NaN           0.0  0.000000  0.000000  0.226415  1.461306
# 3             NaN           1.0  1.000000  1.000000  1.245283  0.047807
# 4             NaN           0.0  0.000000  0.000000  0.000000  1.167086
# ..            ...           ...       ...       ...       ...       ...
# 224      1.651913           NaN  3.166667  3.166667  1.010638  1.068596
# 225    -18.681631           NaN  0.000000  0.000000  0.000000  1.111513
# 226     -2.770408           NaN  1.409091  1.409091  3.263158  1.118982
# 227      0.000000           NaN  0.000000  0.000000  0.000000  1.130705
# 228     40.408163           NaN  4.227273  4.227273  4.894737  1.126716
#
#                    name  team
# 0       Clint Benedict*   OTS
# 1          Sammy Hebert   OTS
# 2           Jake Forbes   HAM
# 3          Jesse Spring   HAM
# 4       Clint Benedict*   MTM
# ..                  ...   ...
# 224       Keith Kinkaid   NJD
# 225      Cory Schneider   NJD
# 226      Louis Domingue   TBL
# 227      Eddie Pasquale   TBL
# 228  Andrei Vasilevskiy   TBL
#
# [229 rows x 30 columns]

# %%
nba_teammates
# Out:
#      Year  age        gp        gs        mp        fg       fga       fg%  \
# 0    1956   31  1.235452       NaN  1.572907  1.549725  1.439464  1.099782
# 1    1956   22  1.120143       NaN  1.021312  0.834467  0.902521  0.955636
# 2    1956   32  1.169561       NaN  0.896342  0.625850  0.731156  0.859539
# 3    1956   28  1.186034       NaN  1.327275  1.072886  1.153856  0.958306
# 4    1956   27  1.153089       NaN  1.055787  0.864270  1.005340  0.875555
# ..    ...  ...       ...       ...       ...       ...       ...       ...
# 863  2019   27  1.563542  3.317886  1.606264  2.067620  2.118692  1.002475
# 864  2019   27  0.934064  1.077236  1.399671  1.629034  1.677890  0.997928
# 865  2019   23  0.081223  0.000000  0.377033  0.313276  0.355485  0.909274
# 866  2019   27  1.502624  0.517073  0.909011  0.689207  0.696751  1.027480
# 867  2019   22  0.974675  0.129268  0.950330  0.689207  0.739409  0.941099
#
#            3p       3pa  ...       stl       blk       tov     fouls  \
# 0         NaN       NaN  ...       NaN       NaN       NaN  1.243768
# 1         NaN       NaN  ...       NaN       NaN       NaN  1.088297
# 2         NaN       NaN  ...       NaN       NaN       NaN  1.476975
# 3         NaN       NaN  ...       NaN       NaN       NaN  1.321504
# 4         NaN       NaN  ...       NaN       NaN       NaN  0.932826
# ..        ...       ...  ...       ...       ...       ...       ...
# 863  2.623762  2.450227  ...  1.618815  0.255545  2.157522  1.273343
# 864  2.851916  2.726866  ...  1.133170  1.788814  0.938053  1.331222
# 865  0.342230  0.316158  ...  0.809407  0.000000  0.281416  0.173638
# 866  1.254843  1.106554  ...  0.647526  0.511090  0.281416  0.694551
# 867  1.140766  1.027515  ...  0.647526  1.022179  0.656637  1.041826
#
#           pts  selection             name  pos  team      school
# 0    1.362175        NaN     Jack Coleman   PF   STL         NaN
# 1    0.851359        NaN       Al Ferrari   SF   STL         NaN
# 2    0.574667        NaN     Alex Hannum*   PF   STL         NaN
# 3    0.915211        NaN     Bob Harrison   PG   STL         NaN
# 4    0.776865        NaN     Jack McMahon   PG   STL         NaN
# ..        ...        ...              ...  ...   ...         ...
# 863  2.124551   3.517400  Khris Middleton   SF   MIL   Texas A&M
# 864  1.764654   0.000000   Nikola Mirotić   PF   MIL         NaN
# 865  0.290239   0.000000    Jaylen Morris   SG   MIL         NaN
# 866  0.696574   0.901897       Tony Snell   SF   MIL  New Mexico
# 867  0.673355   0.000000      D.J. Wilson   PF   MIL         NaN
#
# [868 rows x 32 columns]

# %%
team_goalies.drop(['index','Unnamed: 0','Unnamed: 0.1'],axis=1,inplace=True)

# %%
team_goalies.columns
# Out:
# Index(['season', 'age', 'gp', 'gs', 'wins', 'losses', 'ties', 'goals_against',
#        'shots', 'saves', 'save_pct', 'goals_avg', 'shutouts', 'gps', 'minutes',
#        'quality_starts', 'quality_start_pct', 'really_bad_starts',
#        'ga_pct_minus', 'gs_above_avg', 'goals_scored', 'assists', 'points',
#        'plm', 'mpg', 'name', 'team'],
#       dtype='object')

# %%
team_goalies=team_goalies[['season','team','name', 'age', 'gp', 'gs', 'wins', 'losses', 'ties', 'goals_against',
       'shots', 'saves', 'save_pct', 'goals_avg', 'shutouts', 'gps', 'minutes',
       'quality_starts', 'quality_start_pct', 'really_bad_starts',
       'ga_pct_minus', 'gs_above_avg', 'goals_scored', 'assists', 'points',
       'plm', 'mpg']]

# %%
team_goalies
# Out:
#      season team                name  age        gp        gs      wins  \
# 0      1924  OTS     Clint Benedict*   31  1.375000       NaN  1.875000
# 1      1924  OTS        Sammy Hebert   29  0.125000       NaN  0.125000
# 2      1925  HAM         Jake Forbes   27  1.956522       NaN  2.620690
# 3      1925  HAM        Jesse Spring   24  0.065217       NaN  0.000000
# 4      1926  MTM     Clint Benedict*   33  1.694118       NaN  2.086957
# ..      ...  ...                 ...  ...       ...       ...       ...
# 224    2018  NJD       Keith Kinkaid   28  1.411232  1.420142  1.943352
# 225    2018  NJD      Cory Schneider   31  1.376812  1.494886  1.270653
# 226    2019  TBL      Louis Domingue   26  0.888971  0.951220  1.536585
# 227    2019  TBL      Eddie Pasquale   28  0.102574  0.109756  0.146341
# 228    2019  TBL  Andrei Vasilevskiy   24  1.812132  1.939024  2.853659
#
#        losses      ties  goals_against  ...  quality_starts  \
# 0    0.875000       NaN       1.058824  ...             NaN
# 1    0.125000       NaN       0.211765  ...             NaN
# 2    1.379310  2.000000       1.600000  ...             NaN
# 3    0.000000  0.000000       0.000000  ...             NaN
# 4    1.147826  2.727273       1.507745  ...             NaN
# ..        ...       ...            ...  ...             ...
# 224  0.974359  0.962838       1.418709  ...        1.336047
# 225  1.558974  1.925676       1.525782  ...        1.336047
# 226  0.465000  0.000000       0.972939  ...        0.976744
# 227  0.093000  0.000000       0.155670  ...        0.069767
# 228  0.930000  1.372694       1.660483  ...        2.372093
#
#      quality_start_pct  really_bad_starts  ga_pct_minus  gs_above_avg  \
# 0                  NaN                NaN           NaN           NaN
# 1                  NaN                NaN           NaN           NaN
# 2                  NaN                NaN           NaN           NaN
# 3                  NaN                NaN           NaN           NaN
# 4                  NaN                NaN           NaN           NaN
# ..                 ...                ...           ...           ...
# 224           1.060363           0.976864      1.339553      1.651913
# 225           1.007344           1.709512      1.434269    -18.681631
# 226           1.256410           0.459259      1.404085     -2.770408
# 227           0.777666           0.229630      0.000000      0.000000
# 228           1.499284           1.607407      1.142540     40.408163
#
#      goals_scored   assists    points       plm       mpg
# 0             NaN       NaN       NaN       NaN  1.015364
# 1             NaN       NaN       NaN       NaN  0.988414
# 2             0.0  0.000000  0.000000  0.226415  1.461306
# 3             1.0  1.000000  1.000000  1.245283  0.047807
# 4             0.0  0.000000  0.000000  0.000000  1.167086
# ..            ...       ...       ...       ...       ...
# 224           NaN  3.166667  3.166667  1.010638  1.068596
# 225           NaN  0.000000  0.000000  0.000000  1.111513
# 226           NaN  1.409091  1.409091  3.263158  1.118982
# 227           NaN  0.000000  0.000000  0.000000  1.130705
# 228           NaN  4.227273  4.227273  4.894737  1.126716
#
# [229 rows x 27 columns]

# %%
team_goalies=team_goalies[team_goalies.season>1978]

# %%
team_goalies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 111 to 228
# Data columns (total 27 columns):
# season               118 non-null int64
# team                 118 non-null object
# name                 118 non-null object
# age                  118 non-null int64
# gp                   118 non-null float64
# gs                   36 non-null float64
# wins                 118 non-null float64
# losses               118 non-null float64
# ties                 118 non-null float64
# goals_against        118 non-null float64
# shots                118 non-null float64
# saves                118 non-null float64
# save_pct             118 non-null float64
# goals_avg            118 non-null float64
# shutouts             118 non-null float64
# gps                  118 non-null float64
# minutes              118 non-null float64
# quality_starts       36 non-null float64
# quality_start_pct    36 non-null float64
# really_bad_starts    36 non-null float64
# ga_pct_minus         118 non-null float64
# gs_above_avg         118 non-null float64
# goals_scored         34 non-null float64
# assists              118 non-null float64
# points               118 non-null float64
# plm                  118 non-null float64
# mpg                  118 non-null float64
# dtypes: float64(23), int64(2), object(2)
# memory usage: 25.8+ KB

# %%
for col in ['gs','quality_starts','quality_start_pct','really_bad_starts','goals_scored']:
    team_goalies[col].fillna(0,inplace=True)

# %%
team_goalies.plm.dtype==float
# Out:
# True

# %%
grouping_goalie_dict={}
for col in team_goalies.columns:
    if (team_goalies[col].dtype) == int and col != 'season':
        grouping_goalie_dict[col]='mean'
    elif (team_goalies[col].dtype) == float and col != 'season':
        grouping_goalie_dict[col]='mean'
    elif (team_goalies[col].dtype) == object and col != 'team' and col != 'name':
        grouping_goalie_dict[col]='first'

# %%
grouping_goalie_dict
# Out:
# {'age': 'mean',
#  'gp': 'mean',
#  'gs': 'mean',
#  'wins': 'mean',
#  'losses': 'mean',
#  'ties': 'mean',
#  'goals_against': 'mean',
#  'shots': 'mean',
#  'saves': 'mean',
#  'save_pct': 'mean',
#  'goals_avg': 'mean',
#  'shutouts': 'mean',
#  'gps': 'mean',
#  'minutes': 'mean',
#  'quality_starts': 'mean',
#  'quality_start_pct': 'mean',
#  'really_bad_starts': 'mean',
#  'ga_pct_minus': 'mean',
#  'gs_above_avg': 'mean',
#  'goals_scored': 'mean',
#  'assists': 'mean',
#  'points': 'mean',
#  'plm': 'mean',
#  'mpg': 'mean'}

# %%
hart_goalies_average=team_goalies.groupby(['season','team'],as_index=False).agg(grouping_goalie_dict)

# %%
hart_goalies_average.columns
# Out:
# Index(['season', 'team', 'age', 'gp', 'gs', 'wins', 'losses', 'ties',
#        'goals_against', 'shots', 'saves', 'save_pct', 'goals_avg', 'shutouts',
#        'gps', 'minutes', 'quality_starts', 'quality_start_pct',
#        'really_bad_starts', 'ga_pct_minus', 'gs_above_avg', 'goals_scored',
#        'assists', 'points', 'plm', 'mpg'],
#       dtype='object')

# %%
len(['gp', 'gs', 'wins', 'losses', 'ties',
       'goals_against', 'shots', 'saves', 'save_pct', 'goals_avg', 'shutouts',
       'gps', 'minutes', 'quality_starts', 'quality_start_pct',
       'really_bad_starts', 'ga_pct_minus', 'gs_above_avg', 'goals_scored',
       'assists', 'points', 'plm', 'mpg'])
# Out:
# 23

# %% [markdown]
# ## Quick look at goalies

# %%
i = 1
plt.figure(figsize=(25,20))
for col in  ['gp', 'gs', 'wins', 'losses', 'ties',
       'goals_against', 'shots', 'saves', 'save_pct', 'goals_avg', 'shutouts',
       'gps', 'minutes', 'quality_starts', 'quality_start_pct',
       'really_bad_starts', 'ga_pct_minus', 'gs_above_avg', 'goals_scored',
       'assists', 'points', 'plm', 'mpg']:
    with sns.plotting_context('talk'):
        with sns.color_palette('coolwarm'):
            with sns.axes_style('darkgrid'):
                plt.subplot(5,5,i)
                a=sns.lineplot(hart_goalies_average['season'],hart_goalies_average[col])
                plt.tight_layout()
                plt.title(col)
                plt.xticks([], [])
                plt.ylim(hart_goalies_average[col].min()-2.5*hart_goalies_average[col].mean(),
                         hart_goalies_average[col].max()+2.5*hart_goalies_average[col].mean())
                i+=1

# %%
i = 1
plt.figure(figsize=(25,20))
for col in  ['gp', 'gs', 'wins', 'losses', 'ties',
       'goals_against', 'shots', 'saves', 'save_pct', 'goals_avg', 'shutouts',
       'gps', 'minutes', 'quality_starts', 'quality_start_pct',
       'really_bad_starts', 'ga_pct_minus', 'gs_above_avg', 'goals_scored',
       'assists', 'points', 'plm', 'mpg']:
    with sns.plotting_context('talk'):
        with sns.color_palette('coolwarm'):
            with sns.axes_style('darkgrid'):
                plt.subplot(5,5,i)
                a=sns.lineplot(team_goalies['season'],team_goalies[col])
                plt.tight_layout()
                plt.title(col)
                plt.xticks([], [])
                plt.ylim(team_goalies[col].min()-2.5*team_goalies[col].mean(),
                         team_goalies[col].max()+2.5*team_goalies[col].mean())
                i+=1

# %%
hart_goalies_average.hist(figsize=(25,12),color='red')
plt.tight_layout()
plt.show()

# %%
team_goalies.hist(figsize=(25,12),color='skyblue')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quick look at skaters

# %%
group_dict_skaters={}

# %%
team_skaters.columns
# Out:
# Index(['Unnamed: 0', 'index', 'season', 'age', 'gp', 'goals', 'assists',
#        'points', 'plusmin', 'plm', 'goals_ev', 'goals_pp', 'goals_sh',
#        'goals_gw', 'assists_ev', 'assists_pp', 'assists_sh', 'shots', 'toi',
#        'hits', 'faceoff_wins', 'faceoff_losses', 'block', 'faceoff_pct',
#        'shot_pct', 'gpg', 'toi_avg', 'name', 'team', 'pos'],
#       dtype='object')

# %%
team_skaters.drop('Unnamed: 0',axis=1,inplace=True)

# %%
hart_skater_averages=team_skaters.groupby(['season','team'],as_index=False).mean()

# %%
hart_skater_averages
# Out:
#     season team   index        age        gp     goals   assists    points  \
# 0     1940  DET  1947.0  25.173913  0.860627  0.641947  0.641764  0.641838
# 1     1941  BOS  1926.5  25.166667  1.118004  1.443085  1.334776  1.378109
# 2     1942  BRO  1907.0  24.666667  0.927600  0.842407  0.832922  0.836643
# 3     1943  BOS  1888.0  26.470588  1.224412  1.338276  1.270845  1.297585
# 4     1944  TOR  1870.0  22.842105  1.212233  1.247863  1.176302  1.205798
# ..     ...  ...     ...        ...       ...       ...       ...       ...
# 74    2015  MTL   116.0  26.280000  1.028741  1.088191  1.041708  1.058816
# 75    2016  CHI    90.5  26.115385  0.987526  1.146898  1.178412  1.166627
# 76    2017  EDM    64.0  25.269231  1.060045  1.182312  1.161748  1.169432
# 77    2018  NJD    37.5  25.730769  1.015193  1.061526  0.918819  0.971959
# 78    2019  TBL    12.0  26.560000  1.204700  1.540092  1.569090  1.558268
#
#       plusmin       plm  ...     shots       toi      hits  faceoff_wins  \
# 0         NaN  0.600675  ...       NaN       NaN       NaN           NaN
# 1         NaN  0.833553  ...       NaN       NaN       NaN           NaN
# 2         NaN  0.995956  ...       NaN       NaN       NaN           NaN
# 3         NaN  1.238467  ...       NaN       NaN       NaN           NaN
# 4         NaN  1.072860  ...       NaN       NaN       NaN           NaN
# ..        ...       ...  ...       ...       ...       ...           ...
# 74 -18.209032  1.126054  ...  1.022998  1.042975  0.828185      1.218304
# 75  -7.420028  0.761170  ...  1.026545  1.028111  0.684373      1.030091
# 76  -9.146067  1.038345  ...  1.107033  1.070269  1.252348      0.984300
# 77   2.844916  0.989973  ...  0.999386  0.999578  1.050586      0.974947
# 78 -23.689351  1.376427  ...  1.207260  1.201071  1.389554      1.217550
#
#     faceoff_losses     block  faceoff_pct  shot_pct       gpg   toi_avg
# 0              NaN       NaN          NaN       NaN  0.696629       NaN
# 1              NaN       NaN          NaN       NaN  1.213352       NaN
# 2              NaN       NaN          NaN       NaN  0.845999       NaN
# 3              NaN       NaN          NaN       NaN  1.328918       NaN
# 4              NaN       NaN          NaN       NaN  1.177311       NaN
# ..             ...       ...          ...       ...       ...       ...
# 74        1.113516  1.217440     1.141581  0.959156  0.990171  0.965477
# 75        1.042254  1.032332     0.930229  0.918548  1.013593  1.006894
# 76        1.120265  1.164932     0.917295  1.080423  1.119038  0.999766
# 77        1.102075  0.980452     1.022187  0.968153  1.004020  1.017535
# 78        1.160055  1.181250     0.895974  1.184325  1.258792  1.052934
#
# [79 rows x 27 columns]

# %%
hart_skater_averages.drop('index',axis=1,inplace=True)

# %%
hart_skater_averages=hart_skater_averages[hart_skater_averages.season>=1979]

# %%
hart_skater_averages.columns
# Out:
# Index(['season', 'team', 'age', 'gp', 'goals', 'assists', 'points', 'plusmin',
#        'plm', 'goals_ev', 'goals_pp', 'goals_sh', 'goals_gw', 'assists_ev',
#        'assists_pp', 'assists_sh', 'shots', 'toi', 'hits', 'faceoff_wins',
#        'faceoff_losses', 'block', 'faceoff_pct', 'shot_pct', 'gpg', 'toi_avg'],
#       dtype='object')

# %%
i = 1
plt.figure(figsize=(25,20))
for col in  ['gp', 'goals', 'assists', 'points', 'plusmin',
       'plm', 'goals_ev', 'goals_pp', 'goals_sh', 'goals_gw', 'assists_ev',
       'assists_pp', 'assists_sh', 'shots', 'toi', 'hits', 'faceoff_wins',
       'faceoff_losses', 'block', 'faceoff_pct', 'shot_pct', 'gpg', 'toi_avg']:
    with sns.plotting_context('talk'):
        with sns.color_palette('coolwarm'):
            with sns.axes_style('darkgrid'):
                plt.subplot(5,5,i)
                a=sns.lineplot(hart_skater_averages['season'],hart_skater_averages[col])
                plt.tight_layout()
                plt.title(col)
                plt.xticks([], [])
                plt.ylim(hart_skater_averages[col].min()-2*hart_skater_averages[col].mean(),
                         hart_skater_averages[col].max()+2*hart_skater_averages[col].mean())
                i+=1

# %%
i = 1
plt.figure(figsize=(25,20))
for col in  ['gp', 'goals', 'assists', 'points', 'plusmin',
       'plm', 'goals_ev', 'goals_pp', 'goals_sh', 'goals_gw', 'assists_ev',
       'assists_pp', 'assists_sh', 'shots', 'toi', 'hits', 'faceoff_wins',
       'faceoff_losses', 'block', 'faceoff_pct', 'shot_pct', 'gpg', 'toi_avg']:
    with sns.plotting_context('talk'):
        with sns.color_palette('coolwarm'):
            with sns.axes_style('darkgrid'):
                plt.subplot(5,5,i)
                a=sns.lineplot(team_skaters['season'],team_skaters[col])
                plt.tight_layout()
                plt.title(col)
                plt.xticks([], [])
                plt.ylim(team_skaters[col].min()-2*team_skaters[col].mean(),
                         team_skaters[col].max()+2*team_skaters[col].mean())
                i+=1

# %%
hart_skater_averages.hist(figsize=(25,12),color='forestgreen')
plt.tight_layout()
plt.show()

# %%
team_skaters.hist(figsize=(25,12),color='hotpink')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quick look at nba

# %%
nba_teammates.columns
# Out:
# Index(['Year', 'age', 'gp', 'gs', 'mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%',
#        '2p', '2pa', '2p%', 'efg%', 'ft', 'fta', 'ft%', 'orb', 'drb', 'trb',
#        'ast', 'stl', 'blk', 'tov', 'fouls', 'pts', 'selection', 'name', 'pos',
#        'team', 'school'],
#       dtype='object')

# %%
mvp_player_averages = nba_teammates.groupby(['Year','team'],as_index=False).mean()

# %%
mvp_player_averages
# Out:
#     Year team        age        gp        gs        mp        fg       fga  \
# 0   1956  STL  25.454545  1.022805       NaN  1.099664  1.086433  1.094657
# 1   1957  BOS  27.090909  1.051356       NaN  1.164111  1.280567  1.242274
# 2   1958  BOS  28.090909  1.094285       NaN  1.092779  1.206818  1.177849
# 3   1959  STL  27.000000  0.956085       NaN  0.981048  0.969223  0.933193
# 4   1960  PHW  26.090909  1.078998       NaN  1.059106  1.146341  1.140820
# ..   ...  ...        ...       ...       ...       ...       ...       ...
# 59  2015  GSW  26.733333  1.136215  1.093333  0.947688  1.064636  0.978268
# 60  2016  GSW  27.266667  1.146284  1.055198  0.951054  1.053566  0.967602
# 61  2017  OKC  25.733333  1.094544  1.216976  1.041195  1.087549  1.066437
# 62  2018  HOU  28.750000  0.856355  0.908780  1.077030  0.999512  1.027125
# 63  2019  MIL  26.650000  0.975691  1.042764  1.017989  1.032244  1.008156
#
#          fg%        3p  ...       orb       drb       trb       ast       stl  \
# 0   0.980146       NaN  ...       NaN       NaN  1.074019  1.063744       NaN
# 1   1.050271       NaN  ...       NaN       NaN  1.371898  1.249855       NaN
# 2   1.069381       NaN  ...       NaN       NaN  1.203618  1.139367       NaN
# 3   1.106376       NaN  ...       NaN       NaN  1.000504  1.068342       NaN
# 4   1.004999       NaN  ...       NaN       NaN  1.170000  1.092068       NaN
# ..       ...       ...  ...       ...       ...       ...       ...       ...
# 59  1.117778  1.206034  ...  1.009916  1.045979  1.038582  1.124844  1.110122
# 60  1.115480  1.385608  ...  1.026374  1.059956  1.049614  1.179366  0.989753
# 61  1.041699  0.902652  ...  1.291928  1.090149  1.135038  0.928836  0.948865
# 62  0.961008  1.374030  ...  1.043730  1.042803  1.040625  0.880285  0.988299
# 63  1.038050  1.226324  ...  0.941745  1.212159  1.151332  1.111106  0.987477
#
#          blk       tov     fouls       pts  selection
# 0        NaN       NaN  1.060030  1.070004        NaN
# 1        NaN       NaN  1.191176  1.257235        NaN
# 2        NaN       NaN  1.040220  1.160259        NaN
# 3        NaN       NaN  1.032815  0.978481        NaN
# 4        NaN       NaN  0.960098  1.104901        NaN
# ..       ...       ...       ...       ...        ...
# 59  1.377428  0.960452  0.967756  1.048110   0.616090
# 60  1.156275  0.999841  0.963006  1.055569   0.612341
# 61  1.273585  1.032040  1.011756  1.064863   1.141337
# 62  1.013007  1.077238  1.169908  1.050762   1.276922
# 63  1.073288  0.970885  0.911598  1.041959   1.436272
#
# [64 rows x 29 columns]

# %%
mvp_player_averages=mvp_player_averages[mvp_player_averages.Year>=1980]

# %%
mvp_player_averages.columns
# Out:
# Index(['Year', 'team', 'age', 'gp', 'gs', 'mp', 'fg', 'fga', 'fg%', '3p',
#        '3pa', '3p%', '2p', '2pa', '2p%', 'efg%', 'ft', 'fta', 'ft%', 'orb',
#        'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'fouls', 'pts', 'selection'],
#       dtype='object')

# %%
i = 1
plt.figure(figsize=(25,20))
for col in  ['age', 'gp', 'gs', 'mp', 'fg', 'fga', 'fg%', '3p',
       '3pa', '3p%', '2p', '2pa', '2p%', 'efg%', 'ft', 'fta', 'ft%', 'orb',
       'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'fouls', 'pts', 'selection']:
    with sns.plotting_context('talk'):
        with sns.color_palette('coolwarm'):
            with sns.axes_style('darkgrid'):
                plt.subplot(6,6,i)
                a=sns.lineplot(mvp_player_averages['Year'],mvp_player_averages[col])
                plt.tight_layout()
                plt.title(col)
                plt.xticks([], [])
                plt.ylim(mvp_player_averages[col].min()-2*mvp_player_averages[col].mean(),
                         mvp_player_averages[col].max()+2*mvp_player_averages[col].mean())
                i+=1

# %%
i = 1
plt.figure(figsize=(25,20))
for col in  ['age', 'gp', 'gs', 'mp', 'fg', 'fga', 'fg%', '3p',
       '3pa', '3p%', '2p', '2pa', '2p%', 'efg%', 'ft', 'fta', 'ft%', 'orb',
       'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'fouls', 'pts', 'selection']:
    with sns.plotting_context('talk'):
        with sns.color_palette('coolwarm'):
            with sns.axes_style('darkgrid'):
                plt.subplot(6,6,i)
                a=sns.lineplot(nba_teammates['Year'],nba_teammates[col])
                plt.tight_layout()
                plt.title(col)
                plt.xticks([], [])
                plt.ylim(nba_teammates[col].min()-2*nba_teammates[col].mean(),
                         nba_teammates[col].max()+2*nba_teammates[col].mean())
                i+=1

# %%
mvp_player_averages.hist(figsize=(25,12),color='grey')
plt.tight_layout()
plt.show()

# %%
nba_teammates.hist(figsize=(25,12),color='gold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Creating a simple metric for goalies, skaters, and NBAers to measure how good they are - find what stats arew negative and which ones are positive and average them all out... then compare

# %%
team_skaters.columns
# Out:
# Index(['index', 'season', 'age', 'gp', 'goals', 'assists', 'points', 'plusmin',
#        'plm', 'goals_ev', 'goals_pp', 'goals_sh', 'goals_gw', 'assists_ev',
#        'assists_pp', 'assists_sh', 'shots', 'toi', 'hits', 'faceoff_wins',
#        'faceoff_losses', 'block', 'faceoff_pct', 'shot_pct', 'gpg', 'toi_avg',
#        'name', 'team', 'pos'],
#       dtype='object')

# %%
team_goalies.columns
# Out:
# Index(['season', 'team', 'name', 'age', 'gp', 'gs', 'wins', 'losses', 'ties',
#        'goals_against', 'shots', 'saves', 'save_pct', 'goals_avg', 'shutouts',
#        'gps', 'minutes', 'quality_starts', 'quality_start_pct',
#        'really_bad_starts', 'ga_pct_minus', 'gs_above_avg', 'goals_scored',
#        'assists', 'points', 'plm', 'mpg'],
#       dtype='object')

# %%
nba_teammates.columns
# Out:
# Index(['Year', 'age', 'gp', 'gs', 'mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%',
#        '2p', '2pa', '2p%', 'efg%', 'ft', 'fta', 'ft%', 'orb', 'drb', 'trb',
#        'ast', 'stl', 'blk', 'tov', 'fouls', 'pts', 'selection', 'name', 'pos',
#        'team', 'school'],
#       dtype='object')

# %% [markdown]
# ### so in hockey skaters - other than maybe penalty time - everything looks like a positive statistic - in the sense that having a high number in each metric is a good thing

# %%
weird_list={}
for i in range(len(team_skaters)):
    if team_skaters.pos[i] not in ['C','LW','RW','D']:
        weird_list[team_skaters.name[i]]=team_skaters.pos[i]

# %%
# Thank goodness this is a short list

# %%
weird_list
# Out:
# {'Terry Reardon': 'C/RW',
#  'Don Grosso': 'C/LW',
#  'Marcel Bonin': 'W',
#  'Chuck Hamilton': 'LW/D',
#  'Eric Nesterenko': 'C/RW',
#  'Jim Lorentz': 'C/RW',
#  'Mike Walton': 'C/RW',
#  'Eric Messier': 'LW/D'}

# %%
weird_list['Terry Reardon']='C'
weird_list['Don Grosso']='C'
weird_list['Marcel Bonin']='LW'
weird_list['Chuck Hamilton']='RW'
weird_list['Eric Messier']='LW'
weird_list['Eric Nesterenko']='C'
weird_list['Jim Lorentz']='C'
weird_list['Mike Walton']='C'

# %%
for i in range(len(team_skaters)):
    if team_skaters.name[i] in list(weird_list.keys()):
        team_skaters.pos[i]=weird_list[team_skaters.name[i]]

# %%
team_skaters.pos.unique()
# Out:
# array(['RW', 'LW', 'D', 'C'], dtype=object)

# %%
from sklearn.preprocessing import *

# %%
mms = MinMaxScaler()
mas = MaxAbsScaler()
ss = StandardScaler()
rs = RobustScaler()
pt = PowerTransformer()
qt = QuantileTransformer()

# %% [markdown]
# # scaling - this is so important and I have decided to try with 6 types of scaling

# %%
team_skaters2=team_skaters.copy()
for col in team_skaters2.columns:
    if team_skaters2[col].dtype==float or team_skaters2[col].dtype==int and col!='season' and col!='age':
        team_skaters2[col]=mms.fit_transform(team_skaters2[[col]])

# %%
team_skaters2.describe()
# Out:
#              index       season          age           gp        goals  \
# count  1959.000000  1959.000000  1958.000000  1959.000000  1959.000000
# mean      0.500000  1982.152629     0.387241     0.549267     0.121989
# std       0.288896    22.979421     0.183054     0.309035     0.150182
# min       0.000000  1940.000000     0.000000     0.000000     0.000000
# 25%       0.250000  1962.000000     0.260870     0.267050     0.012486
# 50%       0.500000  1984.000000     0.347826     0.679581     0.061205
# 75%       0.750000  2003.000000     0.521739     0.801943     0.182810
# max       1.000000  2019.000000     1.000000     1.000000     1.000000
#
#            assists       points      plusmin          plm     goals_ev  ...  \
# count  1959.000000  1959.000000  1356.000000  1959.000000  1442.000000  ...
# mean      0.129453     0.157814     0.879415     0.099969     0.133791  ...
# std       0.138789     0.170591     0.067331     0.101642     0.158947  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.019684     0.023551     0.865808     0.020945     0.017913  ...
# 50%       0.088577     0.099742     0.900301     0.074536     0.074716  ...
# 75%       0.195013     0.236387     0.913017     0.144768     0.202559  ...
# max       1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#               toi        hits  faceoff_wins  faceoff_losses       block  \
# count  604.000000  330.000000    330.000000      330.000000  330.000000
# mean     0.347546    0.232427      0.087529        0.096679    0.192302
# std      0.236883    0.212413      0.185387        0.197040    0.197432
# min      0.000000    0.000000      0.000000        0.000000    0.000000
# 25%      0.119555    0.068743      0.000000        0.000000    0.047326
# 50%      0.350835    0.171876      0.001070        0.002287    0.133377
# 75%      0.551567    0.353906      0.048120        0.056782    0.263665
# max      1.000000    1.000000      1.000000        1.000000    1.000000
#
#        faceoff_pct     shot_pct          gpg     toi_avg         mean
# count   330.000000  1356.000000  1959.000000  604.000000  1959.000000
# mean      0.244001     0.080824     0.157130    0.477164     0.913260
# std       0.249456     0.074074     0.166847    0.168524     0.057191
# min       0.000000     0.000000     0.000000    0.000000     0.000000
# 25%       0.000000     0.029596     0.026818    0.351273     0.915415
# 50%       0.239774     0.075773     0.109425    0.471523     0.929379
# 75%       0.459465     0.122102     0.235108    0.602940     0.935202
# max       1.000000     1.000000     1.000000    1.000000     1.000000
#
# [8 rows x 27 columns]

# %%
team_skaters2.columns
# Out:
# Index(['index', 'season', 'age', 'gp', 'goals', 'assists', 'points', 'plusmin',
#        'plm', 'goals_ev', 'goals_pp', 'goals_sh', 'goals_gw', 'assists_ev',
#        'assists_pp', 'assists_sh', 'shots', 'toi', 'hits', 'faceoff_wins',
#        'faceoff_losses', 'block', 'faceoff_pct', 'shot_pct', 'gpg', 'toi_avg',
#        'name', 'team', 'pos', 'mean'],
#       dtype='object')

# %% [markdown]
# #### here comes my custom stat!

# %%
for i in range(len(team_skaters2)):
    if team_skaters2.pos[i]!='D':
        team_skaters2['mean'] = team_skaters2[['goals', 'assists', 'points','shots', 'hits','faceoff_pct', 
                                             'shot_pct', 'gpg']].mean(axis=1)
    else:
        team_skaters2['mean'] = team_skaters2[['assists', 'plusmin','shots', 'toi', 'hits', 'block', 
                                             'toi_avg']].mean(axis=1)

# %%
team_skaters2=team_skaters2[['season','team','name','pos', 'age', 'gp', 'goals', 'assists', 'points', 'plusmin',
       'plm', 'goals_ev', 'goals_pp', 'goals_sh', 'goals_gw', 'assists_ev',
       'assists_pp', 'assists_sh', 'shots', 'toi', 'hits', 'faceoff_wins',
       'faceoff_losses', 'block', 'faceoff_pct', 'shot_pct', 'gpg', 'toi_avg','mean']]

# %%
def scale_and_assign_metric_skater(scaler,df):
    df2=df.copy()
    for col in df2.columns:
        if df2[col].dtype==float or df[col].dtype==int and col!='season' and col!='age':
            df2[col]=scaler.fit_transform(df2[[col]])
    for i in range(len(df2)):
        if df2.pos[i]!='D':
            df2['mean_mtrc'] = df2[['goals', 'assists', 'points','shots', 'hits','faceoff_pct', 
                                             'shot_pct', 'gpg']].mean(axis=1)
        else:
            df2['mean_mtrc'] = df2[['assists', 'plusmin','shots', 'toi', 'hits', 'block', 
                                             'toi_avg']].mean(axis=1)
    df2=df2[['season','team','name','pos', 'age', 'gp', 'goals', 'assists', 'points', 'plusmin',
       'plm', 'goals_ev', 'goals_pp', 'goals_sh', 'goals_gw', 'assists_ev',
       'assists_pp', 'assists_sh', 'shots', 'toi', 'hits', 'faceoff_wins',
       'faceoff_losses', 'block', 'faceoff_pct', 'shot_pct', 'gpg', 'toi_avg','mean_mtrc']]
    df2=df2.sort_values(by=['season','team','pos'])
    
    mean_dict_sktrs_all={}
    for s in df2.season.unique():
        mean_dict_sktrs_all[s]=df2[df2.season==s]['mean_mtrc'].max()
    
    df2['year_mean']=df2.season
    
    df2.year_mean=df2.year_mean.map(lambda x: mean_dict_sktrs_all[x])
    
    df2['final_mean_mtrc']=df2.mean_mtrc/df2.year_mean
    
    df2['final_mean_mtrc']=round(df2.final_mean_mtrc*100,2)
    
    return df2

# %%
team_skaters2=scale_and_assign_metric_skater(mms,team_skaters)

# %%
team_skaters2
# Out:
#       season team             name pos       age        gp     goals  \
# 8       1940  DET       Don Grosso   C  0.304348  0.462804  0.033607
# 15      1940  DET  Gus Giesebrecht   C  0.217391  0.479107  0.067214
# 16      1940  DET     Connie Brown   C  0.260870  0.576924  0.134429
# 22      1940  DET        Syd Howe*   C  0.478261  0.739954  0.235251
# 2       1940  DET       Buck Jones   D  0.173913  0.022624  0.000000
# ...      ...  ...              ...  ..       ...       ...       ...
# 1949    2019  TBL    Danick Martel  LW  0.304348  0.086450  0.000000
# 1952    2019  TBL     Ondrej Palat  LW  0.434783  0.675757  0.097980
# 1934    2019  TBL    Ryan Callahan  RW  0.695652  0.547181  0.085733
# 1945    2019  TBL   Mathieu Joseph  RW  0.173913  0.740045  0.159218
# 1948    2019  TBL  Nikita Kucherov  RW  0.347826  0.868621  0.502150
#
#        assists    points   plusmin  ...       toi      hits  faceoff_wins  \
# 8     0.036708  0.044229       NaN  ...       NaN       NaN           NaN
# 15    0.085653  0.097304       NaN  ...       NaN       NaN           NaN
# 16    0.036708  0.097304       NaN  ...       NaN       NaN           NaN
# 22    0.281432  0.327294       NaN  ...       NaN       NaN           NaN
# 2     0.000000  0.000000       NaN  ...       NaN       NaN           NaN
# ...        ...       ...       ...  ...       ...       ...           ...
# 1949  0.015462  0.011819  0.902675  ...  0.036882  0.044610      0.001021
# 1952  0.201012  0.200920  0.900727  ...  0.385803  0.386617      0.002043
# 1934  0.077312  0.100460  0.894885  ...  0.234239  0.330855      0.006128
# 1945  0.100506  0.153644  0.898780  ...  0.321773  0.479554      0.010213
# 1948  0.672619  0.756403  0.861777  ...  0.662994  0.163569      0.000000
#
#       faceoff_losses     block  faceoff_pct  shot_pct       gpg   toi_avg  \
# 8                NaN       NaN          NaN       NaN  0.059126       NaN
# 15               NaN       NaN          NaN       NaN  0.114225       NaN
# 16               NaN       NaN          NaN       NaN  0.190404       NaN
# 22               NaN       NaN          NaN       NaN  0.260756       NaN
# 2                NaN       NaN          NaN       NaN  0.000000       NaN
# ...              ...       ...          ...       ...       ...       ...
# 1949        0.001130  0.004621     0.477693  0.000000  0.000000  0.309563
# 1952        0.016944  0.157098     0.112736  0.075165  0.126979  0.466900
# 1934        0.016944  0.115513     0.273240  0.086539  0.136747  0.340313
# 1945        0.027111  0.064687     0.280884  0.128572  0.188655  0.347812
# 1948        0.003389  0.143236     0.000000  0.156594  0.507916  0.637866
#
#           mean
# 8     0.036708
# 15    0.085653
# 16    0.036708
# 22    0.281432
# 2     0.000000
# ...        ...
# 1949  0.191806
# 1952  0.382623
# 1934  0.304296
# 1945  0.340616
# 1948  0.512195
#
# [1959 rows x 29 columns]

# %%
weird_list2={}
for i in range(len(team_skaters_all)):
    if team_skaters_all.pos[i] not in ['C','LW','RW','D']:
        weird_list2[team_skaters_all.name[i]]=team_skaters_all.pos[i]

# %%
for key,val in weird_list2.items():
    if 'D' in val.split("/"):
        print(key,val)
    else:
        weird_list2[key]='F'
# Out:
# Charlie Conacher* D/RW
# Murray Henderson D/RW
# Red Kelly* C/D
# Howie Young RW/D
# Reggie Fleming W/D
# Chuck Hamilton LW/D
# Leo Labine D/RW
# Doug Mohns D/LW
# Rod Seiling LW/D
# Jim Mikol D/RW
# Norm Armstrong D/LW
# Irv Spencer D/LW
# Jimmy Roberts D/RW
# Chris Evans LW/D
# Bob Neely LW/D
# Lindy Ruff D/RW
# Jim Korn D/LW
# Mathieu Dandenault RW/D
# Eric Messier LW/D

# %%
weird_list2['Charlie Conacher*']='RW'
weird_list2['Murray Henderson']='D'
weird_list2['Red Kelly*']='D'
weird_list2['Howie Young']='D'
weird_list2['Reggie Fleming']='D'
weird_list2['Chuck Hamilton']='RW'
weird_list2['Leo Labine']='RW'
weird_list2['Doug Mohns']='D'
weird_list2['Rod Seiling']='D'
weird_list2['Jim Mikol']='D'
weird_list2['Norm Armstrong']='RW'
weird_list2['Irv Spencer']='D'
weird_list2['Jimmy Roberts']='D'
weird_list2['Chris Evans']='D'
weird_list2['Bob Neely']='D'
weird_list2['Lindy Ruff']='D'
weird_list2['Jim Korn']='D'
weird_list2['Mathieu Dandenault']='RW'
weird_list2['Eric Messier']='LW'

# %%
### look for any names that stand out
weird_list2
# Out:
# {'Hooley Smith*': 'F',
#  'Charlie Conacher*': 'RW',
#  "Jim O'Neil": 'F',
#  'Terry Reardon': 'F',
#  'Dutch Hiller': 'F',
#  'Ray Getliffe': 'F',
#  'Chuck Scherza': 'F',
#  'Don Grosso': 'F',
#  'Murray Henderson': 'D',
#  'Vic Stasiuk': 'F',
#  'Reg Sinclair': 'F',
#  'Joe Klukay': 'F',
#  'Norm Corcoran': 'F',
#  'Marcel Bonin': 'F',
#  'Jack McIntyre': 'F',
#  'Larry Regan': 'F',
#  'Kenny Wharram': 'F',
#  'Red Kelly*': 'D',
#  'Bob Cunningham': 'F',
#  'Brian Smith': 'F',
#  'Howie Young': 'D',
#  'John MacMillan': 'F',
#  'Reggie Fleming': 'D',
#  'Frank Mahovlich*': 'F',
#  'Mel Pearson': 'F',
#  'Chuck Hamilton': 'RW',
#  'Bob Dillabough': 'F',
#  'Leo Labine': 'RW',
#  'Tommy Williams': 'F',
#  'Doug Mohns': 'D',
#  'Bruce Draper': 'F',
#  'Andre Champagne': 'F',
#  'Rod Seiling': 'D',
#  'Jim Mikol': 'D',
#  'Bryan Hextall': 'F',
#  'Norm Armstrong': 'RW',
#  'Bill McCreary': 'F',
#  'Irv Spencer': 'D',
#  'Eric Nesterenko': 'F',
#  'Don McKenney': 'F',
#  'Bobby Rousseau': 'F',
#  'Lou Angotti': 'F',
#  'Earl Ingarfield': 'F',
#  'Jim Lorentz': 'F',
#  'Jimmy Roberts': 'D',
#  "Danny O'Shea": 'F',
#  'Gene Carr': 'F',
#  'Chris Evans': 'D',
#  'Jack Egers': 'F',
#  'Mike Walton': 'F',
#  'Frank St. Marseille': 'F',
#  'John Gould': 'F',
#  'Pete Laframboise': 'F',
#  'Mike Bloom': 'F',
#  'Chuck Lefley': 'F',
#  'Bob Neely': 'D',
#  'Andre Boudrias': 'F',
#  'Pierre Jarry': 'F',
#  'Hartland Monahan': 'F',
#  'Danny Grant': 'F',
#  'Pit Martin': 'F',
#  'Bill Lochead': 'F',
#  'Dave Schultz': 'F',
#  'Darcy Rota': 'F',
#  'Jerry Butler': 'F',
#  'Lucien DeBlois': 'F',
#  'Pat Boutette': 'F',
#  'Tim Kerr': 'F',
#  'Rob McClanahan': 'F',
#  'Derek Smith': 'F',
#  'Mark Johnson': 'F',
#  'Rick MacLeish': 'F',
#  'Lindy Ruff': 'D',
#  'Don Lever': 'F',
#  'Mel Bridgman': 'F',
#  'Rick Paterson': 'F',
#  'Steve Ludzik': 'F',
#  'Dwight Foster': 'F',
#  'Patrik Sundstrom': 'F',
#  'Pierre Aubry': 'F',
#  'Jim Nill': 'F',
#  'Gary McAdam': 'F',
#  'Jim Korn': 'D',
#  'Perry Turnbull': 'F',
#  'Tom Roulston': 'F',
#  'Mark Napier': 'F',
#  'Ron Flockhart': 'F',
#  'Mark Taylor': 'F',
#  'Ric Seiling': 'F',
#  'Colin Patterson': 'F',
#  'Kelly Miller': 'F',
#  'John Anderson': 'F',
#  'Bob Brooke': 'F',
#  'Ron Duguay': 'F',
#  'Mark Osborne': 'F',
#  'Kent Nilsson': 'F',
#  'David Maley': 'F',
#  'Lindsay Carson': 'F',
#  'Mike Allison': 'F',
#  'Mathieu Dandenault': 'RW',
#  'Oleg Saprykin': 'F',
#  'Mark Bell': 'F',
#  'Eric Messier': 'LW',
#  'Brad Malone': 'F',
#  'Mike Hoffman': 'F',
#  'Reid Boucher': 'F',
#  'Alexandre Burrows': 'F',
#  'Nikolay Goldobin': 'F',
#  'Tomas Jurco': 'F',
#  'Zachary Sanford': 'F',
#  'Ryan Hartman': 'F',
#  'Rick Nash': 'F',
#  'Chris Wagner': 'F',
#  'Scott Wilson': 'F',
#  'Jesper Bratt': 'F',
#  'Kristian Vesalainen': 'F'}

# %%
weird_list2['Rick Nash']='LW'
weird_list2['Alexandre Burrows']='RW'
weird_list2['Mike Hoffman']='LW'

# %%
for i in range(len(team_skaters_all)):
    if team_skaters_all.name[i] in list(weird_list2.keys()):
        team_skaters_all.pos[i]=weird_list2[team_skaters_all.name[i]]

# %%
team_skaters_all2=scale_and_assign_metric_skater(mms,team_skaters_all)

# %%
team_skaters_all2[team_skaters_all2.name=='Alex Ovechkin']
# Out:
#        season team           name pos       age        gp     goals   assists  \
# 26415    2006  WSH  Alex Ovechkin  LW  0.088235  0.818914  0.622660  0.398394
# 27295    2007  WSH  Alex Ovechkin  LW  0.117647  0.817332  0.570831  0.347556
# 28141    2008  WSH  Alex Ovechkin  LW  0.147059  0.811348  0.847774  0.378502
# 28994    2009  WSH  Alex Ovechkin  LW  0.176471  0.812095  0.724569  0.429370
# 29880    2010  WSH  Alex Ovechkin  LW  0.205882  0.734014  0.661724  0.480660
# 30763    2011  WSH  Alex Ovechkin  LW  0.235294  0.817588  0.434522  0.446476
# 31685    2012  WSH  Alex Ovechkin  LW  0.264706  0.809631  0.531736  0.234064
# 32545    2013  WSH  Alex Ovechkin  RW  0.294118  0.798635  0.719703  0.332981
# 33390    2014  WSH  Alex Ovechkin  LW  0.323529  0.802285  0.704247  0.239833
# 34270    2015  WSH  Alex Ovechkin  LW  0.352941  0.829729  0.731119  0.238517
# 35163    2016  WSH  Alex Ovechkin  LW  0.382353  0.823783  0.700535  0.186325
# 36647    2017  WSH  Alex Ovechkin  LW  0.411765  0.845864  0.447725  0.308888
# 37556    2018  WSH  Alex Ovechkin  LW  0.441176  0.820033  0.599662  0.292530
# 38453    2019  WSH  Alex Ovechkin  LW  0.470588  0.824664  0.624625  0.293787
#
#          points   plusmin  ...  faceoff_wins  faceoff_losses     block  \
# 26415  0.576560  0.583673  ...           NaN             NaN       NaN
# 27295  0.514709  0.617994  ...           NaN             NaN       NaN
# 28141  0.664455  0.539715  ...      0.005866        0.011690  0.172022
# 28994  0.645452  0.572627  ...      0.006877        0.026160  0.119403
# 29880  0.654902  0.494670  ...      0.008631        0.013134  0.071712
# 30763  0.526575  0.539482  ...      0.005129        0.013007  0.079995
# 31685  0.414597  0.603522  ...      0.005165        0.009824  0.146739
# 32545  0.572559  0.580185  ...      0.000000        0.001692  0.099654
# 33390  0.497646  0.659836  ...      0.001628        0.001032  0.076294
# 34270  0.508284  0.568702  ...      0.001605        0.003053  0.107708
# 35163  0.459739  0.556012  ...      0.000000        0.000000  0.119262
# 36647  0.432284  0.577354  ...      0.000000        0.001041  0.100059
# 37556  0.489998  0.582364  ...      0.002357        0.004981  0.067871
# 38453  0.502759  0.578149  ...      0.000824        0.004179  0.139223
#
#        faceoff_pct  shot_pct       gpg   toi_avg  mean_mtrc  year_mean  \
# 26415          NaN  0.107067  0.213161  0.712301   0.452511   0.477912
# 27295          NaN  0.107140  0.194501  0.698438   0.411596   0.443646
# 28141     0.355362  0.141880  0.290551  0.739008   0.522358   0.522358
# 28994     0.247590  0.104381  0.253882  0.734540   0.510978   0.510978
# 29880     0.440481  0.134325  0.255585  0.700816   0.474882   0.474882
# 30763     0.319379  0.087978  0.151198  0.680749   0.410508   0.410508
# 31685     0.373287  0.123051  0.185106  0.635631   0.376410   0.442987
# 32545     0.000000  0.141018  0.245846  0.646986   0.398867   0.407165
# 33390     0.608196  0.121532  0.242291  0.649775   0.457493   0.457493
# 34270     0.369929  0.130000  0.253456  0.638594   0.448854   0.448854
# 35163     0.000000  0.127231  0.242833  0.641872   0.383839   0.430325
# 36647     0.000000  0.107817  0.151773  0.580019   0.328551   0.384792
# 37556     0.363692  0.125549  0.197579  0.632242   0.381940   0.381940
# 38453     0.191077  0.136022  0.209877  0.658837   0.393423   0.393423
#
#        final_mean_mtrc
# 26415            94.69
# 27295            92.78
# 28141           100.00
# 28994           100.00
# 29880           100.00
# 30763           100.00
# 31685            84.97
# 32545            97.96
# 33390           100.00
# 34270           100.00
# 35163            89.20
# 36647            85.38
# 37556           100.00
# 38453           100.00
#
# [14 rows x 31 columns]

# %%
team_skaters_all2[team_skaters_all2.name=='Stan Mikita*']
# Out:
#       season team          name pos       age        gp     goals   assists  \
# 2620    1959  CBH  Stan Mikita*   C  0.029412  0.020472  0.000000  0.006890
# 2815    1960  CBH  Stan Mikita*   C  0.058824  0.702845  0.091341  0.130948
# 3001    1961  CBH  Stan Mikita*  RW  0.088235  0.729114  0.223352  0.258567
# 3148    1962  CBH  Stan Mikita*  RW  0.117647  0.746425  0.273492  0.364932
# 3285    1963  CBH  Stan Mikita*  RW  0.147059  0.690760  0.345745  0.328688
# 3437    1964  CBH  Stan Mikita*   C  0.176471  0.818668  0.513897  0.425978
# 3591    1965  CBH  Stan Mikita*   C  0.205882  0.831312  0.365620  0.504707
# 3753    1966  CBH  Stan Mikita*   C  0.235294  0.863389  0.392226  0.403445
# 3911    1967  CBH  Stan Mikita*   C  0.264706  0.851169  0.449554  0.515143
# 4199    1968  CBH  Stan Mikita*   C  0.294118  0.777998  0.476563  0.366207
# 4485    1969  CBH  Stan Mikita*   C  0.323529  0.776235  0.326729  0.470517
# 4774    1970  CBH  Stan Mikita*   C  0.352941  0.786465  0.434304  0.345222
# 5107    1971  CBH  Stan Mikita*   C  0.382353  0.720894  0.248784  0.323619
# 5433    1972  CBH  Stan Mikita*   C  0.411765  0.719508  0.268858  0.266377
# 5801    1973  CBH  Stan Mikita*   C  0.441176  0.514452  0.242189  0.325528
# 6194    1974  CBH  Stan Mikita*   C  0.470588  0.742775  0.299658  0.326914
# 6642    1975  CBH  Stan Mikita*   C  0.500000  0.772169  0.336442  0.305961
# 7024    1976  CBH  Stan Mikita*   C  0.529412  0.451169  0.146105  0.243679
# 7458    1977  CBH  Stan Mikita*   C  0.558824  0.544499  0.182691  0.188674
# 7946    1978  CBH  Stan Mikita*   C  0.588235  0.740862  0.177884  0.264627
# 8377    1979  CBH  Stan Mikita*   C  0.617647  0.653045  0.183281  0.225294
# 8627    1980  CBH  Stan Mikita*   C  0.647059  0.172983  0.020309  0.033261
#
#         points   plusmin  ...  faceoff_wins  faceoff_losses  block  \
# 2620  0.004980       NaN  ...           NaN             NaN    NaN
# 2815  0.137722       NaN  ...           NaN             NaN    NaN
# 3001  0.291798       NaN  ...           NaN             NaN    NaN
# 3148  0.392458       NaN  ...           NaN             NaN    NaN
# 3285  0.400013       NaN  ...           NaN             NaN    NaN
# 3437  0.549053       NaN  ...           NaN             NaN    NaN
# 3591  0.536220       NaN  ...           NaN             NaN    NaN
# 3753  0.475754       NaN  ...           NaN             NaN    NaN
# 3911  0.583490       NaN  ...           NaN             NaN    NaN
# 4199  0.488730  0.592731  ...           NaN             NaN    NaN
# 4485  0.493769  0.538461  ...           NaN             NaN    NaN
# 4774  0.453945  0.271739  ...           NaN             NaN    NaN
# 5107  0.350715  0.517577  ...           NaN             NaN    NaN
# 5433  0.318872  0.561062  ...           NaN             NaN    NaN
# 5801  0.349064  0.529992  ...           NaN             NaN    NaN
# 6194  0.376986  0.547806  ...           NaN             NaN    NaN
# 6642  0.379243  0.562896  ...           NaN             NaN    NaN
# 7024  0.244694  0.593236  ...           NaN             NaN    NaN
# 7458  0.222170  0.603366  ...           NaN             NaN    NaN
# 7946  0.274692  0.544641  ...           NaN             NaN    NaN
# 8377  0.248918  0.581169  ...           NaN             NaN    NaN
# 8627  0.033551  0.582617  ...           NaN             NaN    NaN
#
#       faceoff_pct  shot_pct       gpg  toi_avg  mean_mtrc  year_mean  \
# 2620          NaN       NaN  0.000000      NaN   0.002967   0.365248
# 2815          NaN       NaN  0.036348      NaN   0.099090   0.337371
# 3001          NaN       NaN  0.083849      NaN   0.214391   0.420143
# 3148          NaN       NaN  0.100687      NaN   0.282892   0.353783
# 3285          NaN       NaN  0.134919      NaN   0.302341   0.345164
# 3437          NaN       NaN  0.183866      NaN   0.418198   0.420231
# 3591          NaN       NaN  0.130163      NaN   0.384177   0.401492
# 3753          NaN       NaN  0.140560      NaN   0.352996   0.480937
# 3911          NaN       NaN  0.149972      NaN   0.424540   0.424540
# 4199          NaN  0.123171  0.172558      NaN   0.357216   0.357216
# 4485          NaN  0.095076  0.118346      NaN   0.328867   0.432083
# 4774          NaN  0.116432  0.160400      NaN   0.341638   0.415556
# 5107          NaN  0.100805  0.097551      NaN   0.244670   0.554730
# 5433          NaN  0.120806  0.103936      NaN   0.228776   0.477338
# 5801          NaN  0.120554  0.126617      NaN   0.237252   0.395283
# 6194          NaN  0.149612  0.111623      NaN   0.257399   0.482734
# 6642          NaN  0.109686  0.121925      NaN   0.276917   0.406925
# 7024          NaN  0.081609  0.090529      NaN   0.176315   0.380351
# 7458          NaN  0.114642  0.091065      NaN   0.168440   0.412549
# 7946          NaN  0.068519  0.066933      NaN   0.200243   0.428670
# 8377          NaN  0.091490  0.076164      NaN   0.181184   0.425280
# 8627          NaN  0.051103  0.032819      NaN   0.037296   0.450570
#
#       final_mean_mtrc
# 2620             0.81
# 2815            29.37
# 3001            51.03
# 3148            79.96
# 3285            87.59
# 3437            99.52
# 3591            95.69
# 3753            73.40
# 3911           100.00
# 4199           100.00
# 4485            76.11
# 4774            82.21
# 5107            44.11
# 5433            47.93
# 5801            60.02
# 6194            53.32
# 6642            68.05
# 7024            46.36
# 7458            40.83
# 7946            46.71
# 8377            42.60
# 8627             8.28
#
# [22 rows x 31 columns]

# %% [markdown]
# ## onto goalies!

# %%
team_goalies
# Out:
#      season team                name  age        gp        gs      wins  \
# 111    1979  NYI         Glenn Resch   30  1.496173  0.000000  2.284710
# 112    1979  NYI        Billy Smith*   28  1.356994  0.000000  2.196837
# 113    1980  EDM           Jim Corsi   25  1.000000  0.000000  0.790831
# 114    1980  EDM           Don Cutts   26  0.230769  0.000000  0.098854
# 115    1980  EDM         Dave Dryden   38  0.538462  0.000000  0.197708
# ..      ...  ...                 ...  ...       ...       ...       ...
# 224    2018  NJD       Keith Kinkaid   28  1.411232  1.420142  1.943352
# 225    2018  NJD      Cory Schneider   31  1.376812  1.494886  1.270653
# 226    2019  TBL      Louis Domingue   26  0.888971  0.951220  1.536585
# 227    2019  TBL      Eddie Pasquale   28  0.102574  0.109756  0.146341
# 228    2019  TBL  Andrei Vasilevskiy   24  1.812132  1.939024  2.853659
#
#        losses      ties  goals_against  ...  quality_starts  \
# 111  0.615114  2.252252       1.131029  ...        0.000000
# 112  0.702988  0.900901       1.152369  ...        0.000000
# 113  1.383954  0.728873       0.988948  ...        0.000000
# 114  0.197708  0.242958       0.190641  ...        0.000000
# 115  0.691977  0.728873       0.631497  ...        0.000000
# ..        ...       ...            ...  ...             ...
# 224  0.974359  0.962838       1.418709  ...        1.336047
# 225  1.558974  1.925676       1.525782  ...        1.336047
# 226  0.465000  0.000000       0.972939  ...        0.976744
# 227  0.093000  0.000000       0.155670  ...        0.069767
# 228  0.930000  1.372694       1.660483  ...        2.372093
#
#      quality_start_pct  really_bad_starts  ga_pct_minus  gs_above_avg  \
# 111           0.000000           0.000000      0.947314     35.591829
# 112           0.000000           0.000000      1.116013     16.523801
# 113           0.000000           0.000000      1.463719    -12.349936
# 114           0.000000           0.000000      0.000000      0.000000
# 115           0.000000           0.000000      1.764671    -26.074550
# ..                 ...                ...           ...           ...
# 224           1.060363           0.976864      1.339553      1.651913
# 225           1.007344           1.709512      1.434269    -18.681631
# 226           1.256410           0.459259      1.404085     -2.770408
# 227           0.777666           0.229630      0.000000      0.000000
# 228           1.499284           1.607407      1.142540     40.408163
#
#      goals_scored   assists    points       plm       mpg
# 111           0.0  2.127660  2.127660  0.755668  1.104006
# 112           0.0  2.127660  2.127660  4.911839  1.081129
# 113           0.0  4.928571  4.813953  0.920000  0.971228
# 114           0.0  0.000000  0.000000  0.920000  0.832436
# 115           0.0  0.000000  0.000000  0.000000  0.982759
# ..            ...       ...       ...       ...       ...
# 224           0.0  3.166667  3.166667  1.010638  1.068596
# 225           0.0  0.000000  0.000000  0.000000  1.111513
# 226           0.0  1.409091  1.409091  3.263158  1.118982
# 227           0.0  0.000000  0.000000  0.000000  1.130705
# 228           0.0  4.227273  4.227273  4.894737  1.126716
#
# [118 rows x 27 columns]

# %%
team_goalies_all
# Out:
#       Unnamed: 0  season  Unnamed: 0.1  age        gp        gs      wins  \
# 0              0    1918      0.000000   25  1.913043       NaN  1.588235
# 1              1    1918      0.400000   28  0.347826       NaN  0.352941
# 2              2    1918      0.800000   23  0.173913       NaN  0.176471
# 3              3    1918      1.200000   29  1.391304       NaN  1.588235
# 4              4    1918      1.600000   36  0.347826       NaN  0.176471
# ...          ...     ...           ...  ...       ...       ...       ...
# 4274        4274    2019      1.009924   31  1.196691  1.170732  0.804878
# 4275        4275    2019      1.010161   25  1.265074  1.243902  1.097561
# 4276        4276    2019      1.010397   30  1.675368  1.792683  1.463415
# 4277        4277    2019      1.010633   24  1.812132  1.939024  2.853659
# 4278        4278    2019      1.010870   34  1.128309  1.060976  1.170732
#
#         losses      ties  goals_against  ...  really_bad_starts  ga_pct_minus  \
# 0     2.294118       NaN       2.000000  ...                NaN           NaN
# 1     0.352941       NaN       0.403509  ...                NaN           NaN
# 2     0.000000       NaN       0.175439  ...                NaN           NaN
# 3     1.235294       NaN       1.333333  ...                NaN           NaN
# 4     0.529412       NaN       0.614035  ...                NaN           NaN
# ...        ...       ...            ...  ...                ...           ...
# 4274  1.581000  1.029520       1.401032  ...           2.296296      1.651865
# 4275  1.302000  1.715867       1.414005  ...           1.377778      1.459147
# 4276  1.767000  3.088561       1.764263  ...           2.066667      1.390320
# 4277  0.930000  1.372694       1.660483  ...           1.607407      1.142540
# 4278  1.116000  1.372694       1.491840  ...           1.148148      1.583037
#
#       gs_above_avg  goals_scored   assists    points       plm       mpg  \
# 0              NaN           NaN       NaN       NaN       NaN  1.081585
# 1              NaN           NaN       NaN       NaN       NaN  0.978842
# 2              NaN           NaN       NaN       NaN       NaN  0.711885
# 3              NaN           NaN       NaN       NaN       NaN  1.073381
# 4              NaN           NaN       NaN       NaN       NaN  1.067828
# ...            ...           ...       ...       ...       ...       ...
# 4274    -27.765306           NaN  1.409091  1.409091  0.000000  1.014964
# 4275     -8.739796           NaN  1.409091  1.409091  0.000000  1.058837
# 4276     -1.775510           NaN  0.000000  0.000000  1.631579  1.079861
# 4277     40.408163           NaN  4.227273  4.227273  4.894737  1.126716
# 4278    -22.469388           NaN  1.409091  1.409091  3.263158  1.062919
#
#                     name  team
# 0        Clint Benedict*   OTS
# 1             Art Brooks   TRA
# 2           Sammy Hebert   TRA
# 3            Hap Holmes*   TRA
# 4           Bert Lindsay   MTW
# ...                  ...   ...
# 4274          Cam Talbot   PHI
# 4275       Linus Ullmark   BUF
# 4276     Semyon Varlamov   COL
# 4277  Andrei Vasilevskiy   TBL
# 4278            Cam Ward   CHI
#
# [4279 rows x 29 columns]

# %%
team_goalies_all.columns
# Out:
# Index(['Unnamed: 0', 'season', 'Unnamed: 0.1', 'age', 'gp', 'gs', 'wins',
#        'losses', 'ties', 'goals_against', 'shots', 'saves', 'save_pct',
#        'goals_avg', 'shutouts', 'gps', 'minutes', 'quality_starts',
#        'quality_start_pct', 'really_bad_starts', 'ga_pct_minus',
#        'gs_above_avg', 'goals_scored', 'assists', 'points', 'plm', 'mpg',
#        'name', 'team'],
#       dtype='object')

# %%
def scale_and_assign_metric_goalie(scaler,df):
    df2=df.copy()
    
    df2.reset_index(inplace=True)
    
    for col in ['wins','gs','gp','save_pct','shutouts', 'quality_starts','gps',
             'quality_start_pct','gs_above_avg','mpg']:
        df2[col]=scaler.fit_transform(df2[[col]])
        
    for col in ['losses', 'ties', 'goals_avg', 'really_bad_starts', 'ga_pct_minus','plm']:
        df2[col]=scaler.fit_transform((df2[[col]]))
        df2[col]=-1*df2[col]
    
    df2['wins']=df2['wins']*1.1
    df2.gps=df2.gps*0.9
    df2['ties']=0.75*df2['ties']
    df2['save_pct']=2*df2['save_pct']
    df2['gp']=1.5*df2['gp']
    df2['gs_above_avg']=2*df2['gs_above_avg']
    df2['quality_start_pct']=1.1*df2['quality_start_pct']
    df2['really_bad_starts']=2*df2['really_bad_starts']
        
    df2['mean_mtrc']=0
    for i in range(len(df2)):
        df2['mean_mtrc'] = df2[['gp','save_pct','shutouts', 'minutes', 'quality_starts','gps',
             'quality_start_pct','gs_above_avg','mpg','losses', 'ties', 'goals_against','goals_avg', 
                                'really_bad_starts', 'ga_pct_minus','plm']].mean(axis=1)
        
    df2=df2[['season','team','name','age', 'gp', 'gs', 'wins',
       'losses', 'ties', 'goals_against', 'shots', 'saves', 'save_pct',
       'goals_avg', 'shutouts', 'gps', 'minutes', 'quality_starts',
       'quality_start_pct', 'really_bad_starts', 'ga_pct_minus',
       'gs_above_avg', 'goals_scored', 'assists', 'points', 'plm', 'mpg','mean_mtrc']]
    
    df2=df2.sort_values(by=['season','team'])
    
    mean_dict_goalies_all={}
    
    for s in df2.season.unique():
        mean_dict_goalies_all[s]=df2[df2.season==s]['mean_mtrc'].max()
    
    df2['year_mean']=df2.season
    
    df2.year_mean=df2.year_mean.map(lambda x: mean_dict_goalies_all[x])
    
    df2['final_mean_mtrc']=df2.mean_mtrc/df2.year_mean
    
    df2['final_mean_mtrc']=round(df2.final_mean_mtrc*100,2)
    
    return df2

# %%
team_goalies_all2=scale_and_assign_metric_goalie(mas,team_goalies_all)
team_goalies2=scale_and_assign_metric_goalie(mas,team_goalies)

# %%
team_goalies_all2[team_goalies_all2.team=='BOS'].tail(30)
# Out:
#       season team              name  age        gp        gs      wins  \
# 3276    2008  BOS        Tim Thomas   33  0.943037  0.706990  0.490013
# 3306    2009  BOS   Manny Fernandez   34  0.466393  0.347351  0.280008
# 3353    2009  BOS       Tuukka Rask   21  0.016657  0.012865  0.017500
# 3365    2009  BOS        Tim Thomas   34  0.899472  0.681837  0.630017
# 3440    2010  BOS       Tuukka Rask   22  0.696924  0.469628  0.359055
# 3448    2010  BOS        Tim Thomas   35  0.665949  0.505753  0.277451
# 3530    2011  BOS       Tuukka Rask   23  0.470951  0.339130  0.188179
# 3539    2011  BOS        Tim Thomas   36  0.925662  0.690821  0.598752
# 3586    2012  BOS    Anton Khudobin   25  0.016651  0.012839  0.017500
# 3613    2012  BOS       Tuukka Rask   24  0.382964  0.282451  0.192505
# 3626    2012  BOS        Tim Thomas   37  0.982386  0.706127  0.612517
# 3628    2012  BOS       Marty Turco   36  0.083253  0.051355  0.035001
# 3675    2013  BOS    Anton Khudobin   26  0.363812  0.282678  0.247907
# 3702    2013  BOS       Tuukka Rask   25  0.935517  0.686503  0.523359
# 3758    2014  BOS      Chad Johnson   27  0.490717  0.321832  0.324250
# 3796    2014  BOS       Tuukka Rask   26  1.054133  0.811577  0.686648
# 3804    2014  BOS   Niklas Svedberg   24  0.018175  0.013993  0.019074
# 3886    2015  BOS       Tuukka Rask   27  1.208477  0.888825  0.615073
# 3895    2015  BOS    Malcolm Subban   21  0.017264  0.013266  0.000000
# 3896    2015  BOS   Niklas Svedberg   25  0.310751  0.185725  0.126633
# 3934    2016  BOS  Jonas Gustavsson   31  0.414178  0.265213  0.198994
# 3977    2016  BOS       Tuukka Rask   28  1.104475  0.822160  0.560802
# 4041    2017  BOS    Anton Khudobin   30  0.283728  0.191781  0.130762
# 4058    2017  BOS     Zane McIntyre   24  0.141864  0.041096  0.000000
# 4073    2017  BOS       Tuukka Rask   29  1.152644  0.863014  0.691170
# 4083    2017  BOS    Malcolm Subban   23  0.017733  0.013699  0.000000
# 4139    2018  BOS    Anton Khudobin   31  0.529207  0.384289  0.289243
# 4168    2018  BOS       Tuukka Rask   30  0.921845  0.702322  0.614641
# 4222    2019  BOS    Jaroslav Halak   33  0.678303  0.479978  0.389336
# 4263    2019  BOS       Tuukka Rask   31  0.780048  0.583757  0.477822
#
#         losses      ties  goals_against  ...  ga_pct_minus  gs_above_avg  \
# 3276 -0.412583 -0.297633       1.869055  ...     -0.539702      0.033520
# 3306 -0.175551 -0.143539       0.932143  ...     -0.565841      0.001488
# 3353 -0.000000 -0.000000       0.000000  ...     -0.000000      0.000000
# 3365 -0.241383 -0.334925       1.496681  ...     -0.427268      0.044216
# 3440 -0.250597 -0.209021       1.056524  ...     -0.415278      0.135547
# 3448 -0.375896 -0.334434       1.308077  ...     -0.511111      0.024169
# 3530 -0.305139 -0.088818       0.951332  ...     -0.507776      0.015056
# 3539 -0.239752 -0.399682       1.500693  ...     -0.383533      0.155203
# 3586 -0.000000 -0.000000       0.014111  ...     -0.000000      0.000000
# 3613 -0.178949 -0.134927       0.620897  ...     -0.494512      0.017738
# 3626 -0.425004 -0.044976       1.862692  ...     -0.554818      0.020941
# 3628 -0.044737 -0.000000       0.225781  ...     -0.000000      0.000000
# 3675 -0.137395 -0.076738       0.690011  ...     -0.514799      0.008593
# 3702 -0.343489 -0.383688       1.558089  ...     -0.458228      0.044237
# 3758 -0.098257 -0.143702       0.809734  ...     -0.487513      0.019624
# 3796 -0.368463 -0.287405       1.756970  ...     -0.453891      0.064678
# 3804 -0.000000 -0.000000       0.030556  ...     -0.000000      0.000000
# 3886 -0.488729 -0.592542       2.293751  ...     -0.545172      0.019510
# 3895 -0.023273 -0.000000       0.044111  ...     -0.000000      0.000000
# 3896 -0.116364 -0.045580       0.514624  ...     -0.575127      0.001596
# 3934 -0.202656 -0.050718       0.846216  ...     -0.579358     -0.009831
# 3977 -0.495382 -0.405746       2.330805  ...     -0.531078      0.002068
# 4041 -0.141585 -0.049835       0.578184  ...     -0.701083     -0.004584
# 4058 -0.094390 -0.049835       0.326155  ...     -0.000000      0.000000
# 4073 -0.471951 -0.249175       2.031055  ...     -0.618974      0.002704
# 4083 -0.023598 -0.000000       0.044476  ...     -0.000000      0.000000
# 4139 -0.136648 -0.340596       1.017188  ...     -0.534805      0.002292
# 4168 -0.318845 -0.243283       1.673006  ...     -0.507795      0.020062
# 4222 -0.239116 -0.208105       1.167527  ...     -0.472637      0.018860
# 4263 -0.282591 -0.260131       1.414005  ...     -0.533090      0.004213
#
#       goals_scored   assists    points       plm       mpg  mean_mtrc  \
# 3276           NaN  0.000000  0.000000 -0.044017  0.784325   0.484381
# 3306           NaN  0.000000  0.000000 -0.045374  0.760474   0.290324
# 3353           NaN  0.000000  0.000000 -0.000000  0.777131   0.239565
# 3365           NaN  1.780000  1.780000 -0.136123  0.781690   0.488605
# 3440           NaN  4.150000  4.150000 -0.052778  0.731545   0.406642
# 3448           NaN  0.000000  0.000000 -0.211112  0.729720   0.320254
# 3530           NaN  0.000000  0.000000 -0.042845  0.717887   0.292178
# 3539           NaN  4.578947  4.578947 -0.278491  0.770809   0.499811
# 3586           0.0  0.000000  0.000000 -0.000000  0.781537   0.234107
# 3613           0.0  0.000000  0.000000 -0.084426  0.729995   0.257800
# 3626           0.0  1.369231  1.348485 -0.000000  0.740037   0.486464
# 3628           0.0  0.000000  0.000000 -0.084426  0.679937   0.166682
# 3675           0.0  0.000000  0.000000 -0.316329  0.737267   0.241361
# 3702           0.0  2.277778  2.216216 -0.000000  0.751239   0.473712
# 3758           0.0  0.000000  0.000000 -0.000000  0.714604   0.318526
# 3796           0.0  3.079365  3.031250 -0.064516  0.745455   0.493141
# 3804           0.0  0.000000  0.000000 -0.000000  0.778923   0.230606
# 3886           NaN  0.000000  0.000000 -0.332724  0.736962   0.487143
# 3895           NaN  0.000000  0.000000 -0.000000  0.393601   0.075763
# 3896           NaN  0.000000  0.000000 -0.000000  0.634841   0.236448
# 3934           NaN  0.000000  0.000000 -0.000000  0.671594   0.260842
# 3977           NaN  1.769231  1.769231 -0.000000  0.736322   0.468667
# 4041           NaN  2.714286  2.714286 -0.064673  0.729305   0.202246
# 4058           NaN  0.000000  0.000000 -0.000000  0.548838   0.160422
# 4073           NaN  5.428571  5.428571 -0.000000  0.746485   0.440781
# 4083           NaN  0.000000  0.000000 -0.000000  0.408744   0.114984
# 4139           NaN  3.166667  3.166667 -0.058481  0.739084   0.296360
# 4168           NaN  3.166667  3.166667 -0.116961  0.755898   0.434585
# 4222           NaN  5.636364  5.636364 -0.000000  0.725630   0.380854
# 4263           NaN  2.818182  2.818182 -0.188823  0.720386   0.378186
#
#       year_mean  final_mean_mtrc
# 3276   0.579621            83.57
# 3306   0.533508            54.42
# 3353   0.533508            44.90
# 3365   0.533508            91.58
# 3440   0.530944            76.59
# 3448   0.530944            60.32
# 3530   0.542889            53.82
# 3539   0.542889            92.07
# 3586   0.531692            44.03
# 3613   0.531692            48.49
# 3626   0.531692            91.49
# 3628   0.531692            31.35
# 3675   0.558220            43.24
# 3702   0.558220            84.86
# 3758   0.568079            56.07
# 3796   0.568079            86.81
# 3804   0.568079            40.59
# 3886   0.549245            88.69
# 3895   0.549245            13.79
# 3896   0.549245            43.05
# 3934   0.516446            50.51
# 3977   0.516446            90.75
# 4041   0.549197            36.83
# 4058   0.549197            29.21
# 4073   0.549197            80.26
# 4083   0.549197            20.94
# 4139   0.546887            54.19
# 4168   0.546887            79.47
# 4222   0.507646            75.02
# 4263   0.507646            74.50
#
# [30 rows x 30 columns]
